# %% [markdown]
# <a href="https://colab.research.google.com/github/danisoaresl/DataAnalytics/blob/main/filtragem_tabela_game_medal_tally.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Quando a tabela for gigante faz dessa forma.

# %%
import pandas as pd
import numpy as np

from google.colab import drive
drive.mount('/content/drive')

# Certifique-se de que o nome do arquivo inclui '.gz'
file_path = '/content/drive/My Drive/game_medal_tally.csv.gz'

# Carregando o CSV comprimido em gzip
df = pd.read_csv(file_path, compression='gzip')

# Exibindo as primeiras linhas do DataFrame
df.head()

# %% [markdown]
# Filtragem tabela game_medal_tally do site https://basedosdados.org/

# %%
# !pip install basedosdados

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import basedosdados as bd

from google.colab import drive
drive.mount('/content/drive')

file_path = '/content/drive/My Drive/game_medal_tally.csv'

df = pd.read_csv(file_path)

df.head()
