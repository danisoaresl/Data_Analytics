# %% [markdown]
# <a href="https://colab.research.google.com/github/danisoaresl/DataAnalytics/blob/main/filtragem_tabela_atletas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Filtragem de Dados da Tabela de Atletas do Site https://basedosdados.org/

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/drive')

# Substitua pelo caminho correto do seu arquivo CSV
file_path = '/content/drive/My Drive/athlete_bio.csv'

# Carrega o CSV em um DataFrame
df = pd.read_csv(file_path)

# Exibe as primeiras linhas para verificar se foi carregado corretamente
df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    athlete_id             name   sex birth_date  birth_year  height  weight  \
# 0      923137     Rafael Pérez  Male        NaN         NaN     NaN     NaN
# 1     2303703     Álvaro Ledón  Male        NaN         NaN     NaN     NaN
# 2      921722  Abelardo Cuevas  Male        NaN         NaN     NaN     NaN
# 3     2303702     V. Fernández  Male        NaN         NaN     NaN     NaN
# 4     2303699         M. Casas  Male        NaN         NaN     NaN     NaN
#
#   country country_noc                                        description  \
# 0    Cuba         CUB                                                NaN
# 1    Cuba         CUB                                                NaN
# 2    Cuba         CUB  Abelardo Cuevas was a Cuban oboist, hornist, s...
# 3    Cuba         CUB                                                NaN
# ...
